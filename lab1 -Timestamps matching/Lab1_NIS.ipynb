# %%
import time
import numpy as np
from numba import njit

# %%
def make_timestamps(fps: int, st_ts: float, fn_ts: float) -> np.ndarray: # функция генерации записей с камеры
    """
    Create array of timestamps. This array is discretized with fps,
    but not evenly.
    Timestamps are assumed sorted nad unique.
    Parameters:
    - fps: int
        Average frame per second
    - st_ts: float
        First timestamp in the sequence
    - fn_ts: float
        Last timestamp in the sequence
    Returns:
        np.ndarray: synthetic timestamps
    """
    # generate uniform timestamps
    timestamps = np.linspace(st_ts, fn_ts, int((fn_ts - st_ts) * fps))
    # add an fps noise
    timestamps += np.random.randn(len(timestamps))
    timestamps = np.unique(np.sort(timestamps))
    return timestamps

# %%
@njit #====================== использовать ли numba компилятор для функции ============================
def match_timestamps(timestamps1: np.ndarray, timestamps2: np.ndarray) -> np.ndarray:     
    images_count = timestamps1.shape[0]
    max_number_image = timestamps2.shape[0] - 1
    results = np.zeros(images_count, dtype=np.int32)
    tik = 0

    for image, image_time in enumerate(timestamps1):
        dif = np.abs(timestamps2[tik] - image_time)
        while np.abs(timestamps2[min(tik+1, max_number_image)] - image_time) < dif:
            tik += 1
            dif = np.abs(timestamps2[tik] - image_time)
        results[image] = tik
    #===============================================================================================
    return results

# %%
timestamps1 = make_timestamps(30, time.time() - 100, time.time() + 3600 * 2)
timestamps2 = make_timestamps(60, time.time() + 200, time.time() + 3600 * 2.5)

# %%
print(f'Размерность timestamps для первой камеры - {len(timestamps1)}')
print(f'Размерность timestamps для второй камеры - {len(timestamps2)}')
time_start = time.perf_counter()
for i in range(100):
    answer = match_timestamps(timestamps1, timestamps2)
    print(f'Номер запуска алгоритма - {i}, время работы алгоритма: {(time.perf_counter() - time_start)/(i+1)}')
print(f'Среднее время работы: {(time.perf_counter() - time_start)/100}')
# Out:
# Размерность timestamps для первой камеры - 218998
# Размерность timestamps для второй камеры - 527998
# Номер запуска алгоритма - 0, время работы алгоритма: 0.25404077600001074
# Номер запуска алгоритма - 1, время работы алгоритма: 0.1297554884999954
# Номер запуска алгоритма - 2, время работы алгоритма: 0.08822384733332456
# Номер запуска алгоритма - 3, время работы алгоритма: 0.0674826332499947
# Номер запуска алгоритма - 4, время работы алгоритма: 0.05502061659999526
# Номер запуска алгоритма - 5, время работы алгоритма: 0.046711905833319634
# Номер запуска алгоритма - 6, время работы алгоритма: 0.04078800514285571
# Номер запуска алгоритма - 7, время работы алгоритма: 0.03636270462499169
# Номер запуска алгоритма - 8, время работы алгоритма: 0.032907208999997946
# Номер запуска алгоритма - 9, время работы алгоритма: 0.030368062799993822
# Номер запуска алгоритма - 10, время работы алгоритма: 0.028087281909093195
# Номер запуска алгоритма - 11, время работы алгоритма: 0.026178235583330434
# Номер запуска алгоритма - 12, время работы алгоритма: 0.024556282923072104
# Номер запуска алгоритма - 13, время работы алгоритма: 0.023170474714285256
# Номер запуска алгоритма - 14, время работы алгоритма: 0.02196263646666618
# Номер запуска алгоритма - 15, время работы алгоритма: 0.02090807987499943
# Номер запуска алгоритма - 16, время работы алгоритма: 0.019971745000000683
# Номер запуска алгоритма - 17, время работы алгоритма: 0.01914085566666775
# Номер запуска алгоритма - 18, время работы алгоритма: 0.018398613578944224
# Номер запуска алгоритма - 19, время работы алгоритма: 0.017730622999999925
# Номер запуска алгоритма - 20, время работы алгоритма: 0.01713073542856862
# Номер запуска алгоритма - 21, время работы алгоритма: 0.016588721545453856
# Номер запуска алгоритма - 22, время работы алгоритма: 0.01609341386956262
# Номер запуска алгоритма - 23, время работы алгоритма: 0.015641094833332165
# Номер запуска алгоритма - 24, время работы алгоритма: 0.015225346560000616
# Номер запуска алгоритма - 25, время работы алгоритма: 0.01484051307692023
# Номер запуска алгоритма - 26, время работы алгоритма: 0.014484119629628367
# Номер запуска алгоритма - 27, время работы алгоритма: 0.014162531178572278
# Номер запуска алгоритма - 28, время работы алгоритма: 0.013857193172411983
# Номер запуска алгоритма - 29, время работы алгоритма: 0.013582976433330412
# Номер запуска алгоритма - 30, время работы алгоритма: 0.013317575838707471
# Номер запуска алгоритма - 31, время работы алгоритма: 0.013068229531249642
# Номер запуска алгоритма - 32, время работы алгоритма: 0.012835341878788617
# Номер запуска алгоритма - 33, время работы алгоритма: 0.012612638529410159
# Номер запуска алгоритма - 34, время работы алгоритма: 0.012402274057142547
# Номер запуска алгоритма - 35, время работы алгоритма: 0.01220472961111025
# Номер запуска алгоритма - 36, время работы алгоритма: 0.012017758135133024
# Номер запуска алгоритма - 37, время работы алгоритма: 0.01184076531578919
# Номер запуска алгоритма - 38, время работы алгоритма: 0.01167204969230613
# Номер запуска алгоритма - 39, время работы алгоритма: 0.011522227275000319
# Номер запуска алгоритма - 40, время работы алгоритма: 0.011362538292681764
# Номер запуска алгоритма - 41, время работы алгоритма: 0.01121087590476171
# Номер запуска алгоритма - 42, время работы алгоритма: 0.011065679767440552
# Номер запуска алгоритма - 43, время работы алгоритма: 0.010926946840907125
# Номер запуска алгоритма - 44, время работы алгоритма: 0.010795776755554067
# Номер запуска алгоритма - 45, время работы алгоритма: 0.010668020739130854
# Номер запуска алгоритма - 46, время работы алгоритма: 0.01054753138297888
# Номер запуска алгоритма - 47, время работы алгоритма: 0.010431555145833235
# Номер запуска алгоритма - 48, время работы алгоритма: 0.010327559265306263
# Номер запуска алгоритма - 49, время работы алгоритма: 0.010274506339999333
# Номер запуска алгоритма - 50, время работы алгоритма: 0.010171645647059288
# Номер запуска алгоритма - 51, время работы алгоритма: 0.010071010307692281
# Номер запуска алгоритма - 52, время работы алгоритма: 0.009973798490565695
# Номер запуска алгоритма - 53, время работы алгоритма: 0.00988086625925967
# Номер запуска алгоритма - 54, время работы алгоритма: 0.009812904927271533
# Номер запуска алгоритма - 55, время работы алгоритма: 0.009733927785713295
# Номер запуска алгоритма - 56, время работы алгоритма: 0.009650678403507603
# Номер запуска алгоритма - 57, время работы алгоритма: 0.00956989177586232
# Номер запуска алгоритма - 58, время работы алгоритма: 0.009491416101693977
# Номер запуска алгоритма - 59, время работы алгоритма: 0.00941580218333229
# Номер запуска алгоритма - 60, время работы алгоритма: 0.009342530459015447
# Номер запуска алгоритма - 61, время работы алгоритма: 0.009293650967742172
# Номер запуска алгоритма - 62, время работы алгоритма: 0.009224802650793309
# Номер запуска алгоритма - 63, время работы алгоритма: 0.009158272703125192
# Номер запуска алгоритма - 64, время работы алгоритма: 0.009093488230769253
# Номер запуска алгоритма - 65, время работы алгоритма: 0.009030703363636707
# Номер запуска алгоритма - 66, время работы алгоритма: 0.008969848567164209
# Номер запуска алгоритма - 67, время работы алгоритма: 0.008911300691176608
# Номер запуска алгоритма - 68, время работы алгоритма: 0.00885397056521654
# Номер запуска алгоритма - 69, время работы алгоритма: 0.008798066042857045
# Номер запуска алгоритма - 70, время работы алгоритма: 0.008744189070422553
# Номер запуска алгоритма - 71, время работы алгоритма: 0.008691690847221089
# Номер запуска алгоритма - 72, время работы алгоритма: 0.008641280657533484
# Номер запуска алгоритма - 73, время работы алгоритма: 0.008591642972972394
# Номер запуска алгоритма - 74, время работы алгоритма: 0.008543312599999808
# Номер запуска алгоритма - 75, время работы алгоритма: 0.008496018776315251
# Номер запуска алгоритма - 76, время работы алгоритма: 0.008450709870129532
# Номер запуска алгоритма - 77, время работы алгоритма: 0.008406014923076409
# Номер запуска алгоритма - 78, время работы алгоритма: 0.00836236103797362
# Номер запуска алгоритма - 79, время работы алгоритма: 0.008319948737499772
# Номер запуска алгоритма - 80, время работы алгоритма: 0.00827881332098755
# Номер запуска алгоритма - 81, время работы алгоритма: 0.008238693829267925
# Номер запуска алгоритма - 82, время работы алгоритма: 0.008199680012047935
# Номер запуска алгоритма - 83, время работы алгоритма: 0.00816143716666656
# Номер запуска алгоритма - 84, время работы алгоритма: 0.008124321576470346
# Номер запуска алгоритма - 85, время работы алгоритма: 0.008087781383720582
# Номер запуска алгоритма - 86, время работы алгоритма: 0.008052095195401454
# Номер запуска алгоритма - 87, время работы алгоритма: 0.008016999704545148
# Номер запуска алгоритма - 88, время работы алгоритма: 0.007983176168539339
# Номер запуска алгоритма - 89, время работы алгоритма: 0.007965094799999406
# Номер запуска алгоритма - 90, время работы алгоритма: 0.007932660571427632
# Номер запуска алгоритма - 91, время работы алгоритма: 0.00790094305434724
# Номер запуска алгоритма - 92, время работы алгоритма: 0.007869535043010894
# Номер запуска алгоритма - 93, время работы алгоритма: 0.007838786648935251
# Номер запуска алгоритма - 94, время работы алгоритма: 0.007808708999999381
# Номер запуска алгоритма - 95, время работы алгоритма: 0.007809919552083026
# Номер запуска алгоритма - 96, время работы алгоритма: 0.007780903979381169
# Номер запуска алгоритма - 97, время работы алгоритма: 0.007752472306122501
# Номер запуска алгоритма - 98, время работы алгоритма: 0.007723791565656093
# Номер запуска алгоритма - 99, время работы алгоритма: 0.007695493339999757
# Среднее время работы: 0.007698334579999937
